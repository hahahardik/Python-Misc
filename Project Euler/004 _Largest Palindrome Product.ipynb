# %% [markdown]
# # 004 - Largest Palindrome
#
# A palindromic number reads the same both ways. The largest palindrome made from the product of two 2-digit numbers is 9009 = 91 × 99.
#
# Find the largest palindrome made from the product of two 3-digit numbers.
#
# ### I have taken a case for any number of digits.

# %%
def palindrome(digit):
    
    # Empty list to store palindromes
    palindromes = []
    
    for i in range(10**(digit-1), 10**digit):
        for j in range(10**(digit-1), 10**digit):
            # Converted to string to check it with its reverse
            if str(i*j) == str(i*j)[::-1]:
                palindromes.append(i*j)
            else:
                continue
                
    # Returning a set to remove multiple entries
    return set(palindromes)

# %%
# Argument '2' gives all the palindrome numbers obtained from multiplication of any two '2-digit' numbers
twod_pals = palindrome(2)
print(twod_pals)
# Out:
# {4224, 8448, 646, 777, 2442, 525, 5005, 1551, 272, 656, 5775, 4884, 666, 2332, 414, 676, 4004, 4774, 2552, 555, 6776, 686, 2992, 9009, 434, 949, 8118, 696, 4664, 3003, 444, 828, 3773, 575, 2112, 6336, 7227, 323, 1221, 5445, 8008, 585, 969, 4554, 3663, 464, 848, 2002, 979, 595, 2772, 5335, 1881, 858, 989, 7007, 737, 484, 868, 999, 616, 1001, 5225, 363, 1771, 494, 242, 252, 6006, 888, 121, 5115, 636, 767}

# %%
# Max can be obtained as follows
max(twod_pals)
# Out:
# 9009

# %%
#For 3 Digits
print(palindrome(3))
# Out:
# {405504, 182281, 235532, 561165, 65556, 20502, 88088, 79897, 391193, 444444, 770077, 57375, 12321, 94249, 653356, 301103, 63536, 77877, 888888, 131131, 536635, 510015, 69696, 24642, 92229, 47174, 366663, 61516, 84048, 249942, 575575, 602206, 90209, 45154, 36963, 59495, 106601, 432234, 28782, 96369, 51315, 262262, 65656, 43134, 57475, 471174, 80008, 71817, 354453, 407704, 41114, 184481, 589985, 24742, 616616, 92329, 393393, 84148, 39093, 420024, 98489, 67776, 276672, 329923, 45254, 303303, 59595, 14541, 159951, 82128, 73937, 37073, 133331, 485584, 51415, 512215, 88288, 747747, 57575, 198891, 26862, 577775, 225522, 551155, 604406, 63736, 86268, 108801, 434434, 55555, 33033, 61716, 98589, 147741, 53535, 121121, 67876, 409904, 14641, 330033, 82228, 239932, 565565, 65856, 213312, 618816, 80208, 26962, 801108, 49494, 72027, 252252, 657756, 631136, 41314, 487784, 135531, 69996, 461164, 514415, 840048, 92529, 70007, 696696, 16761, 749947, 84348, 723327, 76167, 67976, 174471, 22922, 227722, 5
# ...

# %%
#Max 3-digit palindrome
max(palindrome(3))
# Out:
# 906609
